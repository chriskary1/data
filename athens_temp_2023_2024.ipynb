# %% [markdown]
# **Διάβασμα αρχείου θερμοκρασιών από το Github**
#
# **Το αρχείο athens_temp_2023_2024.csv περιέχει θερμοκρασίες της πόλης των Αθηνών κατά την διετία 2023-24**

# %% [markdown]
# **Επισκόπηση πρώτων γραμμών**

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/chriskary1/data/refs/heads/main/athens_temp_2023_2024.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#            ds     y
# 0  2023-01-01  20.0
# 1  2023-01-02  22.1
# 2  2023-01-03  18.5
# 3  2023-01-04  22.5
# 4  2023-01-05  23.7

# %% [markdown]
# **Δημιουργία μοντέλου**

# %%
from prophet import Prophet

m = Prophet()
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp39ut7501/8ulvwvw8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp39ut7501/db9002ye.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66054', 'data', 'file=/tmp/tmp39ut7501/8ulvwvw8.json', 'init=/tmp/tmp39ut7501/db9002ye.json', 'output', 'file=/tmp/tmp39ut7501/prophet_model131rlfni/prophet_model-20250919190215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:02:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:02:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# **Δημιουργία πρόβλεψης 6 μήνων μετά το 2024**

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Γραφήματα τάσης, ετήσιας και εβδομαδιαίας εποχικότητας**

# %%
plot_components_plotly(m, forecast)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
